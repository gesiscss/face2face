# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import powerlaw
import matplotlib.pyplot as plt
import numpy as np
from sociopatterns.imports.load_all_data import Data
from sociopatterns.statistics.distribution import *

# %%
def get_distances(delta_t_list, distance_measure="D", amount_xmin=3000):
    list_D = []
    #list_sigma = []
    #list_mu = []
    list_x = []
    for i in range(amount_xmin):
        fit = powerlaw.Fit(delta_t_list, xmin=i)
        #if np.isnan(fit.power_law.D) == False:
        list_D.append(fit.truncated_power_law.D)
        #list_sigma.append(fit.power_law.sigma)
        #list_mu.append(fit.power_law.alpha)
        list_x.append(i)
        #else:
        #    pass
    return [list_D,list_x]
    #res = [i / j for i, j in zip(list_sigma, list_mu)] 
    
    #fig, ax1 = plt.subplots()
    #ax1.plot(list_x,list_D,linestyle='-', color='b')
    
    #ax2 = ax1.twinx()
    #ax2.plot(list_x,list_sigma,linestyle='--', color ='g')
    
    #ax3 = ax1.twinx()
    #ax3 = ax1.twiny()
    #ax3.plot(list_mu,list_sigma,linestyle='--', color='r')
    
def plot_distances(liste):
    plt.plot(liste[1],liste[0],linestyle='-', color='b')
    #plt.plot(list_x,list_sigma,linestyle='--', color ='g')
    #plt.plot(list_x,res,linestyle='--', color='r')
    plt.show()
    #return [list_D,res,list_sigma,list_mu]

# %%
df_hospital = Data("hospital")
x_y_list_hospital, delta_t_list_hospital = calculate_contact_duration(df_hospital)
liste_hospital = get_distances(delta_t_list_hospital)
# Out:
# Calculating best minimal value for power law fit
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan

# %%
plot_distances(liste_hospital)

# %%
df_HT09 = Data("HT09")
x_y_list_HT09, delta_t_list_HT09 = calculate_contact_duration(df_HT09)
liste_HT09 = get_distances(delta_t_list_HT09)
# Out:
# Calculating best minimal value for power law fit
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan

# %%
plot_distances(liste_HT09)

# %%
df_InVS13 = Data("InVS13")
x_y_list_InVS13, delta_t_list_InVS13 = calculate_contact_duration(df_InVS13)
liste_InVS13 = get_distances(delta_t_list_InVS13)
# Out:
# Calculating best minimal value for power law fit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-562d44a695c2> in <module>
#       1 df_InVS13 = Data("InVS13")
#       2 x_y_list_InVS13, delta_t_list_InVS13 = calculate_contact_duration(df_InVS13)
# ----> 3 liste_InVS13 = get_distances(delta_t_list_InVS13)
#
# <ipython-input-3-574f58c680ca> in get_distances(delta_t_list, distance_measure, amount_xmin)
#       7         fit = powerlaw.Fit(delta_t_list, xmin=i)
#       8         #if np.isnan(fit.power_law.D) == False:
# ----> 9         list_D.append(fit.truncated_power_law.D)
#      10         #list_sigma.append(fit.power_law.sigma)
#      11         #list_mu.append(fit.power_law.alpha)
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in __getattr__(self, name)
#     170                          discrete_approximation=self.discrete_approximation,
#     171                          parameter_range=parameter_range,
# --> 172                          parent_Fit=self))
#     173             return getattr(self, name)
#     174         else:
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in __init__(self, xmin, xmax, discrete, fit_method, data, parameters, parameter_range, initial_parameters, discrete_approximation, parent_Fit, **kwargs)
#     608
#     609         if (data is not None) and not (parameter_range and self.parent_Fit):
# --> 610             self.fit(data)
#     611
#     612
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in fit(self, data, suppress_output)
#     635                 self.initial_parameters(data),
#     636                 full_output=1,
# --> 637                 disp=False)
#     638         self.parameters(parameters)
#     639         if not self.in_range():
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     414             'initial_simplex': initial_simplex}
#     415
# --> 416     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     417     if full_output:
#     418         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     557
#     558     for k in range(N + 1):
# --> 559         fsim[k] = func(sim[k])
#     560
#     561     ind = numpy.argsort(fsim)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in <lambda>(params)
#     632         parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
#     633             fmin(
# --> 634                 lambda params: fit_function(params),
#     635                 self.initial_parameters(data),
#     636                 full_output=1,
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in fit_function(params)
#     623             def fit_function(params):
#     624                 self.parameters(params)
# --> 625                 return -sum(self.loglikelihoods(data))
#     626         elif self.fit_method=='KS':
#     627             def fit_function(params):
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in loglikelihoods(self, data)
#     952         """
#     953         from numpy import log
# --> 954         return log(self.likelihoods(data))
#     955
#     956     def plot_ccdf(self, data=None, ax=None, survival=True, **kwargs):
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in likelihoods(self, data)
#     944         Another name for the probabilities or probability density function.
#     945         """
# --> 946         return self.pdf(data)
#     947
#     948     def loglikelihoods(self, data):
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in pdf(self, data)
#    1435             likelihoods[likelihoods==0] = 10**float_info.min_10_exp
#    1436         else:
# -> 1437             likelihoods = Distribution.pdf(self, data)
#    1438         return likelihoods
#    1439
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in pdf(self, data)
#     822         if not self.discrete:
#     823             f = self._pdf_base_function(data)
# --> 824             C = self._pdf_continuous_normalizer
#     825             likelihoods = f*C
#     826         else:
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in _pdf_continuous_normalizer(self)
#    1397         from mpmath import gammainc
#    1398         C = ( self.Lambda**(1-self.alpha) /
# -> 1399                 float(gammainc(1-self.alpha,self.Lambda*self.xmin)))
#    1400         return C
#    1401
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\expintegrals.py in gammainc(ctx, z, a, b, regularized)
#     167     # Upper gamma
#     168     elif lower_modified:
# --> 169         return ctx._upper_gamma(z, a, regularized)
#     170     # Lower gamma
#     171     elif upper_modified:
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\expintegrals.py in _upper_gamma(ctx, z, a, regularized)
#     215             r = z-1
#     216             return [([ctx.exp(nega), a], [1, r], [], G, [1, -r], [], 1/nega)]
# --> 217         return ctx.hypercomb(h, [z], force_series=True)
#     218     except ctx.NoConvergence:
#     219         def h(z):
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#     125                 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126                     [ctx.gamma(a) for a in alpha_s] + \
# --> 127                     [ctx.rgamma(b) for b in beta_s] + \
#     128                     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129                 if verbose:
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in hyper(ctx, a_s, b_s, z, **kwargs)
#     227         elif q == 2: return ctx._hyp2f2(a_s, b_s, z, **kwargs)
#     228         elif q == 3: return ctx._hyp2f3(a_s, b_s, z, **kwargs)
# --> 229         elif q == 0: return ctx._hyp2f0(a_s, b_s, z, **kwargs)
#     230     elif p == q+1:
#     231         return ctx._hypq1fq(p, q, a_s, b_s, z, **kwargs)
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in _hyp2f0(ctx, a_s, b_s, z, **kwargs)
#     983         kwargsb = kwargs.copy()
#     984         kwargsb['maxterms'] = kwargsb.get('maxterms', ctx.prec)
# --> 985         return ctx.hypsum(2, 0, (atype,btype), [a,b], z, **kwargsb)
#     986     except ctx.NoConvergence:
#     987         if kwargs.get('force_series'):
#
# ~\Anaconda3\lib\site-packages\mpmath\ctx_mp.py in hypsum(ctx, p, q, flags, coeffs, z, accurate_small, **kwargs)
#     672             v = z._mpc_
#     673         if key not in ctx.hyp_summators:
# --> 674             ctx.hyp_summators[key] = libmp.make_hyp_summator(key)[1]
#     675         summator = ctx.hyp_summators[key]
#     676         prec = ctx.prec
#
# ~\Anaconda3\lib\site-packages\mpmath\libmp\libhyper.py in make_hyp_summator(key)
#     157             add("    %sCIM_%i = ym >> (-offset)" % (W, i))
#     158         else:
# --> 159             raise ValueError
#     160
#     161     l_areal = len(areal)
#
# ValueError:

# %%
plot_distances(liste_InVS13)

# %%
df_InVS15 = Data("InVS15")
x_y_list_InVS15, delta_t_list_InVS15 = calculate_contact_duration(df_InVS15)
liste_InVS15 = get_distances(delta_t_list_InVS15)
# Out:
# Calculating best minimal value for power law fit

# %%
plot_distances(liste_InVS15)

# %%
df_PS09 = Data("PS09")
x_y_list_PS09, delta_t_list_PS09 = calculate_contact_duration(df_PS09)
liste_PS09 = get_distances(delta_t_list_PS09)
# Out:
# Calculating best minimal value for power law fit
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# Not enough data. Returning nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-96a370838be8> in <module>
#       1 df_PS09 = Data("PS09")
#       2 x_y_list_PS09, delta_t_list_PS09 = calculate_contact_duration(df_PS09)
# ----> 3 liste_PS09 = get_distances(delta_t_list_PS09)
#
# <ipython-input-3-574f58c680ca> in get_distances(delta_t_list, distance_measure, amount_xmin)
#       7         fit = powerlaw.Fit(delta_t_list, xmin=i)
#       8         #if np.isnan(fit.power_law.D) == False:
# ----> 9         list_D.append(fit.truncated_power_law.D)
#      10         #list_sigma.append(fit.power_law.sigma)
#      11         #list_mu.append(fit.power_law.alpha)
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in __getattr__(self, name)
#     170                          discrete_approximation=self.discrete_approximation,
#     171                          parameter_range=parameter_range,
# --> 172                          parent_Fit=self))
#     173             return getattr(self, name)
#     174         else:
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in __init__(self, xmin, xmax, discrete, fit_method, data, parameters, parameter_range, initial_parameters, discrete_approximation, parent_Fit, **kwargs)
#     608
#     609         if (data is not None) and not (parameter_range and self.parent_Fit):
# --> 610             self.fit(data)
#     611
#     612
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in fit(self, data, suppress_output)
#     635                 self.initial_parameters(data),
#     636                 full_output=1,
# --> 637                 disp=False)
#     638         self.parameters(parameters)
#     639         if not self.in_range():
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     414             'initial_simplex': initial_simplex}
#     415
# --> 416     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     417     if full_output:
#     418         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     557
#     558     for k in range(N + 1):
# --> 559         fsim[k] = func(sim[k])
#     560
#     561     ind = numpy.argsort(fsim)
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in <lambda>(params)
#     632         parameters, negative_loglikelihood, iter, funcalls, warnflag, = \
#     633             fmin(
# --> 634                 lambda params: fit_function(params),
#     635                 self.initial_parameters(data),
#     636                 full_output=1,
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in fit_function(params)
#     623             def fit_function(params):
#     624                 self.parameters(params)
# --> 625                 return -sum(self.loglikelihoods(data))
#     626         elif self.fit_method=='KS':
#     627             def fit_function(params):
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in loglikelihoods(self, data)
#     952         """
#     953         from numpy import log
# --> 954         return log(self.likelihoods(data))
#     955
#     956     def plot_ccdf(self, data=None, ax=None, survival=True, **kwargs):
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in likelihoods(self, data)
#     944         Another name for the probabilities or probability density function.
#     945         """
# --> 946         return self.pdf(data)
#     947
#     948     def loglikelihoods(self, data):
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in pdf(self, data)
#    1435             likelihoods[likelihoods==0] = 10**float_info.min_10_exp
#    1436         else:
# -> 1437             likelihoods = Distribution.pdf(self, data)
#    1438         return likelihoods
#    1439
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in pdf(self, data)
#     822         if not self.discrete:
#     823             f = self._pdf_base_function(data)
# --> 824             C = self._pdf_continuous_normalizer
#     825             likelihoods = f*C
#     826         else:
#
# ~\Anaconda3\lib\site-packages\powerlaw.py in _pdf_continuous_normalizer(self)
#    1397         from mpmath import gammainc
#    1398         C = ( self.Lambda**(1-self.alpha) /
# -> 1399                 float(gammainc(1-self.alpha,self.Lambda*self.xmin)))
#    1400         return C
#    1401
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\expintegrals.py in gammainc(ctx, z, a, b, regularized)
#     167     # Upper gamma
#     168     elif lower_modified:
# --> 169         return ctx._upper_gamma(z, a, regularized)
#     170     # Lower gamma
#     171     elif upper_modified:
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\expintegrals.py in _upper_gamma(ctx, z, a, regularized)
#     215             r = z-1
#     216             return [([ctx.exp(nega), a], [1, r], [], G, [1, -r], [], 1/nega)]
# --> 217         return ctx.hypercomb(h, [z], force_series=True)
#     218     except ctx.NoConvergence:
#     219         def h(z):
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in hypercomb(ctx, function, params, discard_known_zeros, **kwargs)
#     125                 v = ctx.fprod([ctx.hyper(a_s, b_s, z, **kwargs)] + \
#     126                     [ctx.gamma(a) for a in alpha_s] + \
# --> 127                     [ctx.rgamma(b) for b in beta_s] + \
#     128                     [ctx.power(w,c) for (w,c) in zip(w_s,c_s)])
#     129                 if verbose:
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in hyper(ctx, a_s, b_s, z, **kwargs)
#     227         elif q == 2: return ctx._hyp2f2(a_s, b_s, z, **kwargs)
#     228         elif q == 3: return ctx._hyp2f3(a_s, b_s, z, **kwargs)
# --> 229         elif q == 0: return ctx._hyp2f0(a_s, b_s, z, **kwargs)
#     230     elif p == q+1:
#     231         return ctx._hypq1fq(p, q, a_s, b_s, z, **kwargs)
#
# ~\Anaconda3\lib\site-packages\mpmath\functions\hypergeometric.py in _hyp2f0(ctx, a_s, b_s, z, **kwargs)
#     983         kwargsb = kwargs.copy()
#     984         kwargsb['maxterms'] = kwargsb.get('maxterms', ctx.prec)
# --> 985         return ctx.hypsum(2, 0, (atype,btype), [a,b], z, **kwargsb)
#     986     except ctx.NoConvergence:
#     987         if kwargs.get('force_series'):
#
# ~\Anaconda3\lib\site-packages\mpmath\ctx_mp.py in hypsum(ctx, p, q, flags, coeffs, z, accurate_small, **kwargs)
#     672             v = z._mpc_
#     673         if key not in ctx.hyp_summators:
# --> 674             ctx.hyp_summators[key] = libmp.make_hyp_summator(key)[1]
#     675         summator = ctx.hyp_summators[key]
#     676         prec = ctx.prec
#
# ~\Anaconda3\lib\site-packages\mpmath\libmp\libhyper.py in make_hyp_summator(key)
#     157             add("    %sCIM_%i = ym >> (-offset)" % (W, i))
#     158         else:
# --> 159             raise ValueError
#     160
#     161     l_areal = len(areal)
#
# ValueError:

# %%
plot_distances(liste_PS09)

# %%
df_SFHH09 = Data("SFHH09")
x_y_list_SFHH09, delta_t_list_SFHH09 = calculate_contact_duration(df_SFHH09)
liste_SFHH09 = get_distances(delta_t_list_SFHH09)
# Out:
# Calculating best minimal value for power law fit

# %%
plot_distances(liste_SFHH09)

# %%
df_sg09 = Data("sg09")
x_y_list_sg09, delta_t_list_sg09 = calculate_contact_duration(df_sg09)
liste_sg09 = get_distances(delta_t_list_sg09)
# Out:
# Calculating best minimal value for power law fit

# %%
plot_distances(liste_sg09)

# %%
df_thiers11 = Data("thiers11")
x_y_list_thiers11, delta_t_list_thiers11 = calculate_contact_duration(df_thiers11)
liste_thiers11 = get_distances(delta_t_list_thiers11)
# Out:
# Calculating best minimal value for power law fit

# %%
plot_distances(liste_thiers11)

# %%
df_thiers12 = Data("thiers12")
x_y_list_thiers12, delta_t_list_thiers12 = calculate_contact_duration(df_thiers12)
liste_thiers12 = get_distances(delta_t_list_thiers12)
# Out:
# Calculating best minimal value for power law fit

# %%
plot_distances(liste_thiers12)

# %%
df_thiers13 = Data("thiers13")
x_y_list_thiers13, delta_t_list_thiers13 = calculate_contact_duration(df_thiers13)
liste_thiers13 = get_distances(delta_t_list_thiers13)
# Out:
# Calculating best minimal value for power law fit

# %%
plot_distances(liste_thiers13)

# %%
df_WS16 = Data("WS16")
x_y_list_WS16, delta_t_list_WS16 = calculate_contact_duration(df_WS16)
liste_WS16 = get_distances(delta_t_list_WS16)

# %%
plot_distances(liste_WS16)
